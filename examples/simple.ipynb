# %%
# Importing numpy
import numpy as np

# Defining a list of numers
a = [1, 2]

# sum over the list
b = np.sum(a)

# print the result
print(b)
# Out:
# 3

# %%
# Importing matplotlib
import matplotlib.pyplot as plt

# creating dataset
x = 0.1 * np.asarray(range(100))
x = np.random.rand(100) + x

# plot the result
plt.plot(x)
plt.show()
